# %%
import pandas as pd 
times = pd.read_csv("test_graphs_from_all_teams_sorted.csv")
print(times.columns)
# Out:
# Index(['Unnamed: 0', 'first_implementations/1.py',
#        'first_implementations/3.py', 'first_implementations/4.py',
#        'first_implementations/5.py', 'first_implementations/6.py',
#        'first_implementations/7.py', 'first_implementations/8.py',
#        'first_implementations/9.py', 'first_implementations/10.py',
#        'first_implementations/11.py', 'first_implementations/12.py',
#        'first_implementations/13.py', 'first_implementations/14.py',
#        'first_implementations/15.py', 'first_implementations/16.py',
#        'first_implementations/17.py', 'first_implementations/18.py',
#        'first_implementations/19.py', 'first_implementations/20.py',
#        'first_implementations/21.py', 'first_implementations/22.py',
#        'first_implementations/23.py', 'first_implementations/24.py', 'graph',
#        'average_graph_time'],
#       dtype='object')

# %%
n = times.shape[0]
for i in range(n):
	print(times.loc[i, ['graph', 'average_graph_time']])

times[['graph', 'average_graph_time']].to_csv('average_graph_times.csv')
# Out:
# graph                 grafi/3/n_10000_bidirectional_a_star_killer.txt
# average_graph_time                                          86.049358
# Name: 0, dtype: object
# graph                 grafi/22/dense-n10k_k4.txt
# average_graph_time                      73.75312
# Name: 1, dtype: object
# graph                 grafi/10/test_graph_3_subgraphs_9600.txt
# average_graph_time                                   65.130372
# Name: 2, dtype: object
# graph                 grafi/4/dense10000.txt
# average_graph_time                 58.241625
# Name: 3, dtype: object
# graph                 grafi/11/dense_diamond_10000_k-1.txt
# average_graph_time                               48.287491
# Name: 4, dtype: object
# graph                 grafi/22/dense-n5k_k0.txt
# average_graph_time                    45.398747
# Name: 5, dtype: object
# graph                 grafi/2/magnetic_n5000_k10.txt
# average_graph_time                         45.018955
# Name: 6, dtype: object
# ...
